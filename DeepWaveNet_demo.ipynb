# %%
# Assuming that the uie_uieb folder is placed in the users google drive
# therefore to access the code, mount the drive to colab
# another way to do is to directly clone the Deep WaveNet repository using the below command
# !git clone https://github.com/pksvision/Deep-WaveNet-Underwater-Image-Restoration.git 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# once cloned or mounted, switch to uie_uieb folder
# %cd /content/drive/MyDrive/uie_uieb/
# Out:
# /content/drive/MyDrive/uie_uieb

# %%
# for users convenience, we have provided the sample images to test
# Note: actual testing dataset utilized in the case of UIEB is different consisting of 90 images.
# Provided sample images are just subset of it just to show the demo
# The clean counterparts are also available
# To test on original test set, follow the steps given in original repo
# As described in original repo, to test, just run the following command
# !python test.py
# Out:
# Color correction module for underwater images
# 100% 18/18 [00:20<00:00,  1.16s/it, name: 877.png | old [hw]: 720/1280 | new [hw]: 720/1280]
# Total time taken in secs : 20.817174911499023
# Per image (avg): 1.1565097173055012

# %%
from google.colab.patches import cv2_imshow # for image display
# for reading the images
from skimage import io 
import cv2 as cv

# read and display the degraded image first
image = io.imread('./hazy_test/807.png') 
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FE455892C50>

# %%
# Now display the corresponding enhanced image
image = io.imread('./facades/Ours_UIEB/807.png') 
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FE45589A390>
